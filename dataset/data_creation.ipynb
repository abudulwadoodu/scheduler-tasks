# %%
import pandas as pd

data = pd.read_excel("materials.xlsx")
data.columns
# Out:
# Index(['Unnamed: 0', 'Code', 'Code.1', 'Description', 'Type', 'Unit\n',
#        'Rate £', 'Extracted Price', 'New Rate (ex VAT)', 'New Rate INCL VAT)',
#        '% change', 'Discount', 'Wastage', 'Cost Code', 'Supplier Code',
#        'Supplier', 'URL', 'Comments', 'Source\n', 'Web', 'Status',
#        'Unnamed: 21', 'InApp Comment'],
#       dtype='object')

# %%
data[data['Source\n']=='mytub.co'][:10].to_excel("mytub_samples.xlsx", index=False)
