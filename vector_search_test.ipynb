# %%
from database.vectordb import VectorDB

vdb = VectorDB()
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 167.64it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'id': 9,
#   'item_id': 5,
#   'content': 'Baleno',
#   'item_name': 'HttpBin',
#   'source_name': 'Flipkart',
#   'distance': 0.0},
#  {'id': 10,
#   'item_id': 5,
#   'content': 'Baleno',
#   'item_name': 'HttpBin',
#   'source_name': 'Flipkart',
#   'distance': 0.0},
#  {'id': 7,
#   'item_id': 4,
#   'content': 'Jeep Compass.',
#   'item_name': 'HttpBin',
#   'source_name': 'Flipkart',
#   'distance': 0.810358464717865}]

# %%
vdb.similarity_search("Baleno", top_k=3, filters={"item_type": "Four Wheeler"})
# Out:
# [{'id': 9,
#   'item_id': 5,
#   'content': 'Baleno',
#   'item_name': 'HttpBin',
#   'source_name': 'Flipkart',
#   'distance': 0.0},
#  {'id': 10,
#   'item_id': 5,
#   'content': 'Baleno',
#   'item_name': 'HttpBin',
#   'source_name': 'Flipkart',
#   'distance': 0.0},
#  {'id': 7,
#   'item_id': 4,
#   'content': 'Jeep Compass.',
#   'item_name': 'HttpBin',
#   'source_name': 'Flipkart',
#   'distance': 0.810358464717865}]

# %%
vdb.add_document(15, "test ipynb data")

# %%
vdb.similarity_search("waterproof winter jacket", top_k=3, filters={})
# Out:
# [{'id': 20,
#   'item_id': 15,
#   'content': 'Insulated parka with fleece lining and detachable hood.',
#   'item_name': 'Waterproof Winter Jacket',
#   'source_name': 'Ebay',
#   'distance': 0.5581539273262024},
#  {'id': 22,
#   'item_id': 17,
#   'content': 'Heavyweight 100% cotton sweatshirt with kangaroo pocket.',
#   'item_name': 'Unisex Cotton Hoodie',
#   'source_name': 'Ebay',
#   'distance': 0.6738235354423523},
#  {'id': 21,
#   'item_id': 16,
#   'content': 'Lightweight breathable mesh sneakers with responsive cushioning.',
#   'item_name': 'Running Shoes',
#   'source_name': 'Ebay',
#   'distance': 0.7794548273086548}]
